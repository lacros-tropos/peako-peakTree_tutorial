# %% [markdown]
# ## 8. Convert a netcdf file
#
# A full file of spectra in netcdf can also be converted conveniently.
#
# <div class="alert alert-block alert-warning">
# <b>Warning:</b> <br />
# Do not run the cells below during the lecture. <br />
# Depending on the compute power, processing might take 30 minutes or more and require 10GB of ram.
# </div>

# %%
import datetime

import peakTree
import peakTree.helpers as h

import netCDF4

# %%
pTB = peakTree.peakTreeBuffer(config_file='instrument_config.toml', system='rpg94_hyytiala')

pTB.load('../data/240114_080000_P09_ZEN.LV0', load_to_ram=True)

# %%
pTB.assemble_time_height('output/')

# %%
with netCDF4.Dataset('../data/20240114_0800_Hyy_peakTree.nc4') as ncd:
    print(ncd)
# Out:
# <class 'netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     description: peakTree processing
#     location: Hyytiälä
#     institution:
#     contact:
#     creation_time: 2025-03-04 16:50 UTC
#     settings: {'grid_time': False, 'max_no_nodes': 15, 'tot_spec_scaling': 1, 'polarimetry': 'LDR', 'smooth_cut_sequence': 'sc', 'decoupling': -28.5, 'station_altitude': 150, 'peak_finding_params': {'chirp0': {'thres_factor_co': False, 'thres_factor_cx': 4, 'smooth_in_dB': False, 't_avg': 9, 'h_avg': 0, 'span': 0.23, 'smooth_polyorder': 2, 'prom_thres': 0.8, 'width_thres': 0}, 'chirp1': {'thres_factor_co': False, 'thres_factor_cx': 4, 'smooth_in_dB': False, 't_avg': 5, 'h_avg': 0, 'span': 0.23, 'smooth_polyorder': 2, 'prom_thres': 0.8, 'width_thres': 0}, 'chirp2': {'thres_factor_co': False, 't_avg': 0, 'h_avg': 0, 'span': 0.3, 'smooth_polyorder': 2, 'prom_thres': 0.5, 'width_thres': 0}, 'thres_factor_co': False, 'thres_factor_cx': 4, 'smooth_in_dB': False, 't_avg': 0, 'h_avg': 0, 'span': 0.3, 'smooth_polyorder': 2, 'prom_thres': 0.5, 'width_thres': 0, 'vel_step': np.float64(0.019069302827119827)}}
#     inputinfo: {'rpgpy': '0.15.10', 'sw': np.uint16(560)}
#     commit_id: 23bfd09
#     branch: master
#     day: 14
#     month: 1
#     year: 2024
#     dimensions(sizes): time(1118), range(370), nodes(15), vel(1024), mode(1), chirp(3)
#     variables(dimensions): int32 timestamp(time), float32 time(time), float32 range(range), float32 height(range), float32 velocity(vel, chirp), float32 Z(time, range, nodes), float32 v(time, range, nodes), float32 width(time, range, nodes), float32 skew(time, range, nodes), int32 bound_l(time, range, nodes), int32 bound_r(time, range, nodes), float32 threshold(time, range, nodes), float32 parent(time, range, nodes), float32 decoupling(mode), float32 LDR(time, range, nodes), float32 ldrmax(time, range, nodes), float32 ldrmin(time, range, nodes), float32 ldrleft(time, range, nodes), float32 ldrright(time, range, nodes), float32 prominence(time, range, nodes), float32 no_nodes(time, range), float32 part_not_reproduced(time, range)
#     groups:
